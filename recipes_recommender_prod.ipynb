# %% [markdown]
# # Capstone Term 2 - Project
#
# * Marcos Bittencourt
# ---
# * Contributors
#     * Todd McCullough [Git](https://github.com/tamccullough)
#     * Savya Sharma [Git](https://github.com/SavyaSharma)
#     * Marko Topitch [Git](https://github.com/TopMarko)
# ---

# %% [markdown]
# ### Initialize Modules and Data

# %% [markdown]
# ##### Import the Needed Modules

# %%
import pandas as pd
import numpy as np
import heapq
from math import floor

# %% [markdown]
# ##### Import Surprise
# [Surprise](http://surpriselib.com/) is a Python scikit building and analyzing recommender systems that deal with explicit rating data.

# %%
from surprise import Reader, Dataset
from surprise import KNNWithMeans
from surprise.model_selection import cross_validate

# %% [markdown]
# ##### Import Data

# %%
recipes_df = pd.read_csv('datasets/recipes-sub.csv')
users_df = pd.read_csv('datasets/users-sub.csv')
master_ratings_df = pd.read_csv('datasets/reviews-sub.csv')

# %%
recipes_df.columns
# Out:
# Index(['recipe_id', 'title', 'servings', 'cals_per_serving', 'prep_time',
#        'cook_time', 'ready_time', 'nutrition', 'ingredients', 'url'],
#       dtype='object')

# %%
recipes_df.head()
# Out:
#    recipe_id                         title  servings  cals_per_serving  \
# 0          1  Chocolate Sandwich Cookies I        12             600.0
# 1          2           Chocolate Pizzelles        12             358.0
# 2          3       Cookie Press Shortbread        24             116.0
# 3          4          Brown Sugar Frosting        16              59.0
# 4          5             Butter Cookies II        36             103.0
#
#     prep_time   cook_time ready_time  \
# 0  30 Minutes   8 Minutes   1 h 10 m
# 1        None        None       None
# 2  25 Minutes  10 Minutes       35 m
# 3        None        None       None
# 4  15 Minutes  10 Minutes   1 h 40 m
#
#                                            nutrition  \
# 0  Per Serving: 600 calories;26.9 g fat;86.6g car...
# 1  Per Serving: 358 calories;22.6 g fat;35.5g car...
# 2  Per Serving: 116 calories;7.8 g fat;10.9g carb...
# 3  Per Serving: 59 calories;0 g fat;15.2g carbohy...
# 4  Per Serving: 103 calories;5.3 g fat;12.7g carb...
#
#                                          ingredients  \
# 0  3 cups all-purpose flour;1 1/2 cups white suga...
# 1  4 eggs;1/4 cup cocoa powder;1 cup white sugar;...
# 2  1 cup butter;1 1/2 cups all-purpose flour;1/2 ...
# 3  1/2 cup packed dark brown sugar;1 tablespoon w...
# 4  1 cup butter;1 cup white sugar;1 egg;2 2/3 cup...
#
#                                                  url
# 0  https://www.allrecipes.com/recipe/10000/chocol...
# 1  https://www.allrecipes.com/recipe/10001/chocol...
# 2  https://www.allrecipes.com/recipe/10003/cookie...
# 3  https://www.allrecipes.com/recipe/10009/brown-...
# 4  https://www.allrecipes.com/recipe/10011/butter...

# %%
users_df.head()
# Out:
#    user_id        AR_id                                         link
# 0        1  naples34102  https://www.allrecipes.com/cook/naples34102
# 1        2      1207425      https://www.allrecipes.com/cook/1207425
# 2        3       183259       https://www.allrecipes.com/cook/183259
# 3        4       162514       https://www.allrecipes.com/cook/162514
# 4        5      1159515      https://www.allrecipes.com/cook/1159515

# %%
master_ratings_df.head()
# Out:
#    reviewer_id  recipe_id  rating        date  \
# 0            1          1       5  2012-02-16
# 1            2          1       2  2004-11-27
# 2            1          1       5  2012-02-16
# 3            3          1       4  2003-08-05
# 4            2          1       2  2004-11-27
#
#                                                 link
# 0  https://www.allrecipes.com/recipe/10000/chocol...
# 1  https://www.allrecipes.com/recipe/10000/chocol...
# 2  https://www.allrecipes.com/recipe/10000/chocol...
# 3  https://www.allrecipes.com/recipe/10000/chocol...
# 4  https://www.allrecipes.com/recipe/10000/chocol...

# %% [markdown]
# ### Data Cleaning

# %%
ratings_df = master_ratings_df.copy()
ratings_df.pop('date')
ratings_df.pop('link')
ratings_df.columns = ['user', 'item', 'rating']

# %%
ratings_df.head()
# Out:
#    user  item  rating
# 0     1     1       5
# 1     2     1       2
# 2     1     1       5
# 3     3     1       4
# 4     2     1       2

# %% [markdown]
# ##### Clean the ratings (Remove duplicates)
#
# Likes change, and making a recipe a few time can change a users rating. This means that users can rate a recipe multiple times. You can see this in the ratings_df.head() above.
#
# For a recommandation system it is best to only use one rating per user.
# For this system, only their most recent review on an item is kept.

# %%
values = ratings_df.values.tolist()
used_user_item_pairs = []

# TODO: Optimize this
clean_values = []
for value in values:
    if value[:2] not in used_user_item_pairs:
        used_user_item_pairs.append(value[:2])
        clean_values.append(value)
    else:
        clean_values[used_user_item_pairs.index(value[:2])] = value

clean_ratings_df = pd.DataFrame(clean_values, columns=['user', 'item', 'rating'])

# %% [markdown]
# The results after cleaning the ratings.

# %%
clean_ratings_df.head()
# Out:
#    user  item  rating
# 0     1     1       5
# 1     2     1       2
# 2     3     1       4
# 3     4     1       5
# 4     5     1       3

# %%
clean_ratings_df.to_csv('datasets/rr-ratings.csv')
recipes_df.to_csv('datasets/rr-recipes.csv')
users_df.to_csv('datasets/rr-users.csv')

# %% [markdown]
# ##### Define a Ratings scale
# This scale is determined by the lowest and highest rating possible.
# In this case the lowest rating is 1, while the highest is 5.

# %%
reader = Reader(rating_scale=(1,5)) # This just defines the rating scale
data = Dataset.load_from_df(clean_ratings_df[['user', 'item', 'rating']], reader=reader)

# %% [markdown]
# ### Build the model
#
# ##### KNN with Means - Surprise
#
# [KNN with Means](https://surprise.readthedocs.io/en/stable/knn_inspired.html#surprise.prediction_algorithms.knns.KNNWithMeans) has been chosen for the recommender, which is a basic collaborative filtering algorithm, taking into account the mean ratings of each user.

# %%
def build_recommender(user_based=False, sim_type='cosine'):
    sim_options = {
        "name": sim_type,
        "user_based": user_based
    }

    return KNNWithMeans(sim_options=sim_options)

# %% [markdown]
# ##### Calculate the Similarity Matrix
#
# Ignoring folds this builds the *Trainset* using [build_full_trainset()](https://surprise.readthedocs.io/en/stable/dataset.html#surprise.dataset.DatasetAutoFolds.build_full_trainset)
#
# The Trainset is built using the data, but then contains more information about the data

# %%
trainset = data.build_full_trainset()

# user_based_recommender = build_recommender(user_based=True)
item_based_recommender = build_recommender()

# User based seems to give a memory error when fit, due to the much larger amount of users than recipes.
# user_based_recommender.fit(trainset)
item_based_recommender.fit(trainset)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %% [markdown]
# ### Evaluate the Model
#
# Using [cross_validation()](https://surprise.readthedocs.io/en/stable/model_selection.html#cross-validation) from surprise, we can quickly evaluate the model using a few metrics.

# %%
cross_validate(item_based_recommender, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9716  0.9782  0.9892  0.9896  0.9718  0.9801  0.0080
# MAE (testset)     0.7189  0.7188  0.7278  0.7278  0.7176  0.7222  0.0046
# Fit time          0.09    0.11    0.11    0.11    0.10    0.10    0.01
# Test time         0.13    0.12    0.14    0.13    0.13    0.13    0.00
# {'test_rmse': array([0.97163128, 0.97818258, 0.98915386, 0.98956806, 0.97175306]),
#  'test_mae': array([0.71890052, 0.71881606, 0.7278457 , 0.72775939, 0.7176301 ]),
#  'fit_time': (0.08956146240234375,
#   0.1103048324584961,
#   0.10791921615600586,
#   0.11022830009460449,
#   0.10349893569946289),
#  'test_time': (0.12713408470153809,
#   0.1244969367980957,
#   0.1385502815246582,
#   0.1281423568725586,
#   0.1281144618988037)}

# %% [markdown]
# ##### Prediction
#
# Using this test to see how a users might rate a specific recipe.

# %%
i = 1
for i in range(150):
    prediction = item_based_recommender.predict(i,167)
    print(round(prediction.est,2), end=', ')
    i = i + 1
# Out:
# 4.46, 4.38, 4.65, 4.65, 4.65, 5, 4.65, 4.65, 4.65, 4.65, 4.46, 4.26, 4.65, 4.65, 4.65, 4.46, 4.65, 4.65, 5, 4.46, 4.65, 4.65, 4.65, 4.65, 4.65, 4.65, 4.65, 4.65, 4.17, 4.65, 5, 4.65, 4.65, 4.65, 4.65, 4.65, 4.65, 4.46, 4.65, 4.65, 4.65, 4.46, 4.65, 4.65, 4.65, 4.65, 4.65, 4.65, 4.46, 4.65, 4.46, 4.65, 4.65, 4.46, 3.76, 4.76, 5, 3.01, 5, 5, 5, 4.76, 2.76, 5, 4.46, 5, 5, 5, 4.76, 5, 1.76, 2.76, 5, 5, 4.65, 4.47, 5, 5, 4.76, 4.76, 2.76, 5, 3.76, 1.76, 1.76, 1.76, 3.76, 4.76, 3.76, 5, 4.46, 2.76, 4.46, 2.76, 1.76, 4.46, 5, 5, 5, 4.46, 4.76, 4.87, 4.65, 4.76, 5, 4.46, 5, 5, 4.76, 5, 5, 4.46, 5, 2.76, 4.46, 5, 5, 4.76, 4.46, 5, 4.46, 3.76, 4.76, 5, 5, 5, 4.8, 4.45, 5, 4.46, 5, 5, 4.76, 4.76, 5, 2.76, 4.46, 4.46, 2.76, 5, 4.76, 4.65, 5, 5, 3.76, 5, 4.76, 3.76, 4.46, 4.46,

# %% [markdown]
# ### Inference
#
# Here is the meat and potatoes(har) of the whole thing.

# %%
def get_r(user_id):
    # Select which system to use. Due to memory constraints, item based is the only viable option
    recommender_system = item_based_recommender

    # User to recommend for
    #user_id = 562

    # N will represent how many items to recommend
    N = 200

    # The setting to a set and back to list is a failsafe.
    rated_items = list(set(clean_ratings_df.loc[clean_ratings_df['user'] == user_id]['item'].tolist()))

    # Self explanitory name
    all_item_ids = list(set(clean_ratings_df['item'].tolist()))

    # New_items just represents all the items not rated by the user
    new_items = [x for x in all_item_ids if x not in rated_items]

    # Estimate ratings for all unrated items
    predicted_ratings = {}
    for item_id in new_items:
        predicted_ratings[item_id] = recommender_system.predict(user_id, item_id).est
        pass

    # Get the item_ids for the top ratings
    recommended_ids = heapq.nlargest(N, predicted_ratings, key=predicted_ratings.get)
    recommended_ids = sorted(recommended_ids)

    # predicted_ratings
    recommended_df = recipes_df.loc[recipes_df['recipe_id'].isin(recommended_ids)].copy()
    recommended_df.set_index('recipe_id', inplace=True)
    recommended_df.insert(1, 'pred_rating', np.zeros(len(recommended_ids)))
    # recommended_df = recipes_df.copy()
    for idx,item_id in enumerate(recommended_ids):
        recommended_df.iloc[idx, recommended_df.columns.get_loc('pred_rating')] =predicted_ratings[item_id]
        pass

    return recommended_df.head(N).sort_values('pred_rating', ascending=False)

# %% [markdown]
# ### Get a Recommendation Based on Ingredients
#
# The final code that will be impletented in a cleaner fashion through the browser interface.

# %%
# ask the user for input
# get their ID number
user_id = int(input('Enter user id: '))

# get them to list some ingredients, currently it breaks if the second or next ingredient is not there
ingredient_list = input('Enter the ingredients separated by commas that you have on hand: ')

# split the input up into an array for the loop
items = np.array(ingredient_list.split(','))

# get the lowest rating
rating = int(input('Enter the lowest rating you\'ll accept: '))

# get their user name
user_name = users_df.loc[users_df['user_id'] == user_id]

# print some details
print('\nuser: ',user_name.iloc[0,1])
print(ingredient_list)
print('\nHere are your recommendations.')
test = get_r(user_id)
for item in items:
    test = test[test['ingredients'].str.contains(item)]
test = test[test['pred_rating'] >= rating]
test
# Out:
# Enter user id: 35
# Enter the ingredients separated by commas that you have on hand: cheese
# Enter the lowest rating you'll accept: 4
#
# user:  10309
# cheese
#
# Here are your recommendations.
#                                                        title  pred_rating  \
# recipe_id
# 505                                         Butter Schnitzel     5.000000
# 967                                        Almond Melon Tart     5.000000
# 891                                       Chile Rellenos Pie     5.000000
# 869                                    Classic Alfredo Sauce     5.000000
# 851                                            Alfredo Light     5.000000
# 828                                             Baked Ziti I     5.000000
# 821                                         American Lasagna     5.000000
# 820        Cheese Ravioli with Fresh Tomato and Artichoke...     5.000000
# 815                                              Alla Checca     5.000000
# 169                     Easy Chocolate Cream Cheese Frosting     5.000000
# 177                                        Banana Split Bars     5.000000
# 212                               Cream Cheese Garlic Spread     5.000000
# 202                                 Broiled Grouper Parmesan     5.000000
# 248                          Black Bean and Corn Quesadillas     5.000000
# 50                                               Calabacitas     5.000000
# 96                                       Cream Cheese Spritz     4.829730
# 648                             Caramel Macchiato Cheesecake     4.818493
# 43                        Baked Chocolate Caramel Cheesecake     4.714286
# 880                    Blueberry and Banana Cream Cheese Pie     4.702128
# 932                                    Clarke Cheesecake Pie     4.692308
# 964                                       Cream Cheese Crust     4.682927
# 60                                 Cheesy Potato Knipla Soup     4.666667
#
#            servings  cals_per_serving   prep_time          cook_time  \
# recipe_id
# 505              12             351.0  25 Minutes         30 Minutes
# 967               8             437.0  30 Minutes         30 Minutes
# 891               6             289.0  15 Minutes         45 Minutes
# 869               2             714.0        None               None
# 851               8             292.0  20 Minutes         20 Minutes
# 828              10             578.0  20 Minutes         35 Minutes
# 821               8             664.0  30 Minutes  1 Hour 15 Minutes
# 820               6             355.0  20 Minutes          5 Minutes
# 815               4             610.0  20 Minutes               None
# 169              24              80.0        None               None
# 177              20             326.0        None               None
# 212              20              78.0   5 Minutes               None
# 202               4             430.0  10 Minutes          6 Minutes
# 248               8             363.0  10 Minutes         30 Minutes
# 50                6             148.0  25 Minutes         15 Minutes
# 96               36              61.0  15 Minutes         10 Minutes
# 648              12             486.0  35 Minutes  1 Hour 28 Minutes
# 43               16             634.0     1 Hour   1 Hour 45 Minutes
# 880              16             353.0  20 Minutes               None
# 932               8             409.0        None               None
# 964               8             238.0        None               None
# 60               12             553.0  45 Minutes         45 Minutes
#
#           ready_time                                          nutrition  \
# recipe_id
# 505             55 m  Per Serving: 351 calories;23.2 g fat;15.7g car...
# 967              3 h  Per Serving: 437 calories;25.6 g fat;47.2g car...
# 891              1 h  Per Serving: 289 calories;19.2 g fat;18.2g car...
# 869             None  Per Serving: 714 calories;72 g fat;5g carbohyd...
# 851             40 m  Per Serving: 292 calories;4.1 g fat;50.5g carb...
# 828             55 m  Per Serving: 578 calories;25.3 g fat;58.4g car...
# 821         1 h 55 m  Per Serving: 664 calories;29.5 g fat;48.3g car...
# 820             25 m  Per Serving: 355 calories;15.5 g fat;42g carbo...
# 815         2 h 20 m  Per Serving: 610 calories;30.7 g fat;69.4g car...
# 169             None  Per Serving: 80 calories;6.3 g fat;6g carbohyd...
# 177             None  Per Serving: 326 calories;19.6 g fat;36.4g car...
# 212              5 m  Per Serving: 78 calories;7.8 g fat;0.7g carboh...
# 202             16 m  Per Serving: 430 calories;24.9 g fat;1.4g carb...
# 248             40 m  Per Serving: 363 calories;14.5 g fat;45.6g car...
# 50              40 m  Per Serving: 148 calories;11.1 g fat;9.6g carb...
# 96              40 m  Per Serving: 61 calories;3.8 g fat;5.9g carboh...
# 648         10 h 3 m  Per Serving: 486 calories;35 g fat;37.1g carbo...
# 43          8 h 45 m  Per Serving: 634 calories;41.9 g fat;59.7g car...
# 880         4 h 20 m  Per Serving: 353 calories;18.2 g fat;46.3g car...
# 932             None  Per Serving: 409 calories;21.5 g fat;47.7g car...
# 964             None  Per Serving: 238 calories;16.8 g fat;18.3g car...
# 60          1 h 30 m  Per Serving: 553 calories;21.7 g fat;74.2g car...
#
#                                                  ingredients  \
# recipe_id
# 505        12 boneless pork loin chops, 3/4 inch thick;2 ...
# 967        1/2 (11 ounce) package pie crust mix;1 cup sou...
# 891        4 eggs;1/2 cup milk;1/4 cup chopped fresh cila...
# 869        3 tablespoons butter;8 fluid ounces heavy whip...
# 851        1 onion, chopped;1 clove garlic, minced;2 teas...
# 828        1 pound dry ziti pasta;1 onion, chopped;1 poun...
# 821        1 1/2 pounds lean ground beef;1 onion, chopped...
# 820        2 (9 ounce) packages fresh cheese ravioli;1 ta...
# 815        5 tomatoes, seeded and diced;4 cloves garlic, ...
# 169        1 (8 ounce) package cream cheese;1/4 cup confe...
# 177        2 cups graham cracker crumbs;1/2 cup white sug...
# 212        2 (8 ounce) packages cream cheese, softened;1/...
# 202        2 pounds fresh grouper fillets;2 tablespoons l...
# 248        2 teaspoons olive oil;3 tablespoons finely cho...
# 50         2 tablespoons olive oil;1 tablespoon butter;2 ...
# 96         1/2 cup shortening;1 (3 ounce) package cream c...
# 648        2 cups graham cracker crumbs;1/2 cup butter, m...
# 43         2 cups graham cracker crumbs;1/2 cup cocoa pow...
# 880        1/2 cup chopped pecans;3 ripe bananas;1 (16 ou...
# 932        1 (9 inch) prepared graham cracker crust;1 (14...
# 964        1/2 cup cream cheese;1 1/2 cups all-purpose fl...
# 60         Soup:;6 baking potatoes, peeled and diced;2 cu...
#
#                                                          url
# recipe_id
# 505        https://www.allrecipes.com/recipe/109451/butte...
# 967        https://www.allrecipes.com/recipe/12370/almond...
# 891        https://www.allrecipes.com/recipe/12115/chile-...
# 869        https://www.allrecipes.com/recipe/12065/classi...
# 851        https://www.allrecipes.com/recipe/11915/alfred...
# 828        https://www.allrecipes.com/recipe/11758/baked-...
# 821        https://www.allrecipes.com/recipe/11729/americ...
# 820        https://www.allrecipes.com/recipe/11723/cheese...
# 815        https://www.allrecipes.com/recipe/11692/alla-c...
# 169        https://www.allrecipes.com/recipe/10342/easy-c...
# 177        https://www.allrecipes.com/recipe/10354/banana...
# 212        https://www.allrecipes.com/recipe/104318/cream...
# 202        https://www.allrecipes.com/recipe/103991/broil...
# 248        https://www.allrecipes.com/recipe/104850/black...
# 50         https://www.allrecipes.com/recipe/100924/calab...
# 96         https://www.allrecipes.com/recipe/10190/cream-...
# 648        https://www.allrecipes.com/recipe/112239/caram...
# 43         https://www.allrecipes.com/recipe/100827/baked...
# 880        https://www.allrecipes.com/recipe/12091/bluebe...
# 932        https://www.allrecipes.com/recipe/12244/clarke...
# 964        https://www.allrecipes.com/recipe/12354/cream-...
# 60         https://www.allrecipes.com/recipe/101188/chees...

# %%
rec_df = pd.read_csv('datasets/recipes-sub.csv')
u_df = pd.read_csv('datasets/users-sub.csv')
r_df = pd.read_csv('datasets/reviews-sub.csv')

# %%
a = 99
r_df.loc[master_ratings_df['reviewer_id'] == a]
# Out:
#      reviewer_id  recipe_id  rating        date  \
# 104           99          3       5  2010-11-21
#
#                                                   link
# 104  https://www.allrecipes.com/recipe/getreviews/r...

# %% [markdown]
# ## Save the Model

# %%
import pickle
filename = 'recipes_recommender_model.sav'
pickle.dump(item_based_recommender, open(filename, 'wb'))

# %%
rr_model = pickle.load(open(filename, 'rb'))

# %%
cross_validate(rr_model, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9783  0.9865  0.9795  0.9817  0.9782  0.9808  0.0031
# MAE (testset)     0.7217  0.7253  0.7224  0.7214  0.7203  0.7222  0.0017
# Fit time          0.08    0.12    0.10    0.11    0.10    0.10    0.01
# Test time         0.13    0.13    0.15    0.13    0.13    0.13    0.01
# {'test_rmse': array([0.97825221, 0.98649248, 0.97948788, 0.98170631, 0.97816223]),
#  'test_mae': array([0.72170042, 0.72532985, 0.72239182, 0.72144593, 0.72027243]),
#  'fit_time': (0.0803375244140625,
#   0.12134957313537598,
#   0.10322785377502441,
#   0.10894298553466797,
#   0.10386300086975098),
#  'test_time': (0.13140225410461426,
#   0.13246560096740723,
#   0.1513383388519287,
#   0.12859630584716797,
#   0.1291794776916504)}
